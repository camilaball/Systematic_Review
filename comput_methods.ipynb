# %%
#packages
import pandas as pd
import analysis as an
import comput_methods_analysis as com

#dataframe
#epi_clocks=pd.read_excel("epi_clocks_final.xlsx")
#epi_clocks=pd.read_excel('epi_all_reviewed.xlsx')
epi_clocks=pd.read_excel('supplementary_table_1.xlsx')

# %%
imputation=com.ImputationMethods(epi_clocks)

# %%
imputation.imputation_present_absent()
# Out:
# False    136
# True      47
# Name: Imputation, dtype: int64

# %%
# imputation.methylation_measurement_imputation_or_not()
# imputation.imputation_per_methylation_measurement()

# %%
feature_selection=com.FeatureSelectionMethods(epi_clocks)
feature_selection.human_feature_selection()

# %%
feature_selection.nonhuman_feature_selection()

# %%
models=com.AgePredictionMethods(epi_clocks)
models.human_models()

# %%
models.nonhuman_models()
